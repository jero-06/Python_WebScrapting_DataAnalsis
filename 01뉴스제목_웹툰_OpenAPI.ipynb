# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# requests 라이브러리 설치여부 확인
! pip show requests
# Out:
# Name: requests
# Version: 2.32.3
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# beautifulsoup4 라이브러리 설치여부 확인
! pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page: https://www.crummy.com/software/BeautifulSoup/bs4/
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\user\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
# reqeusts, bs4 import
import requests
import bs4
# BeautifulSoup 클래스 import
from bs4 import BeautifulSoup

# %%
# requests, bs4 버전 확인하기
print("requests version:", requests.__version__)
print("bs4 version:", bs4.__version__)
# Out:
# requests version: 2.32.3
# bs4 version: 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스 
req_param = {
    'sid': 105
}
# 
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)

# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
}

# requests 의 get() 함수 호출하기 
res = requests.get(url, headers=req_header)
print(res.status_code)
# 응답(response)이 OK 이면
if res.ok:
    # 응답 (response)에서 text 추출
    html = res.text
    # BeautifulSoup 객체 생성  
    soup = BeautifulSoup(html,'html.parser')
    #print(soup)
# CSS 선택자
# print(soup.select("div.sa_text a[href*='mnews/article']"))
print(len(soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews']")))
a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews']")
print(type(a_tags))
# <a> 태그 리스트 순회하기    
for a_tag in a_tags:
    title = a_tag.text.strip()  #<a>title</a>
    link = a_tag['href']        #<a href="link">tile</a>
    print(title, link) 
# 응답(response)이 Error 이면 status code 출력  
else:
    print(f'Error: {res.status_code}')

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

#section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
section_dict = {'정치':100,'경제':101,'사회':102,'생활/문화':103,'세계':104,'IT/과학':105}

def print_news(section_name):  #print_new('생활/문화') 
    sid = section_dict.get(section_name,'102')
    url = f'https://news.naver.com/section/{sid}'
    print(f'{section_name} 뉴스 {url}')

    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/144.0.0.0 Safari/537.3'
    }

    # requests 의 get() 함수 호출하기 
    res = requests.get(url,headers=req_header)
    # 응답(response)이 OK 이면
    if res.ok:    
        # 응답 (response)에서 text 추출
        html = res.text
        # BeautifulSoup 객체 생성  
        soup = BeautifulSoup(html,'html.parser')
        # CSS 선택자
        a_tags = soup.select("div.sa_text a[href*='https://n.news.naver.com/mnews/']")
        # <a> 태그 리스트 순회하기    
        for a_tag in a_tags:    
            title = a_tag.text.strip()  #<a>title</a>
            link = a_tag['href']        #<a href="link">title</a>
            print(title, link)
    # 응답(response)이 Error 이면 status code 출력    
    else:
        print(f'Error Code = {res.status_code}')

# %%
print_news('경제')
# Out:
# 경제 뉴스 https://news.naver.com/section/101
# 워런 버핏처럼 투자한다…'RISE 버크셔포트폴리오TOP10 ETF' [이런펀드 어때요?] https://n.news.naver.com/mnews/article/014/0005558982
#  https://n.news.naver.com/mnews/article/comment/014/0005558982
# AI가 계산하면 1000대 로봇이 작업 척척… 최첨단 물류 승부수[‘제타 스마트센터 부산’ 가 보니] https://n.news.naver.com/mnews/article/082/0001393143
#  https://n.news.naver.com/mnews/article/comment/082/0001393143
# 단일 레버리지 규제후 코스닥 레버리지 '날았다'…자금유입 뚜렷 https://n.news.naver.com/mnews/article/001/0016240434
#  https://n.news.naver.com/mnews/article/comment/001/0016240434
# 서울시, 도시계획시설 입체도면 공개…미아 '층층공원' 첫 적용 https://n.news.naver.com/mnews/article/001/0016241452
#  https://n.news.naver.com/mnews/article/comment/001/0016241452
# “코스닥, 코스피 앞설 조건 갖췄다…로봇·바이오 주목” https://n.news.naver.com/mnews/article/018/0006348456
#  https://n.news.naver.com/mnews/article/comment/018/0006348456
# 폭염에 95GW 넘은 전력수요…휴가 복귀·날씨 변수에 수급 긴장 https://n.news.naver.com/mnews/article/008/0005397428
#  https://n.news.naver.com/mnews/article/comment/215/0001261726
# "재건축 이주비 숨통 트이나"…정부, 추가 대출 공적보증 검토 https://n.news.naver.com/mnews/article/015/0005318948
#  https://n.news.naver.com/mnews/article/comment/015/0005318948
# "60만전자 간다" 삼성전자, 주주환원 최대 200조 전망 https://n.news.naver.com/mnews/article/018/0006348439
#  https://n.news.naver.com/mnews/article/comment/018/0006348439
# 美 변동성 피해 유럽에 몰리는 돈…기업 순익 22% 급증 '4년래 최대' https://n.news.naver.com/mnews/article/018/0006348438
#  https://n.news.naver.com/mnews/article/comment/018/0006348438
# 모건스탠리 “메모리 반도체주 조정 끝...지금이 재진입 기회” https://n.news.naver.com/mnews/article/023/0003992149
#  https://n.news.naver.com/mnews/article/comment/023/0003992149
# 삼성 새만금 투자…10년 만에 다시 구애 https://n.news.naver.com/mnews/article/056/0012234338
#  https://n.news.naver.com/mnews/article/comment/056/0012234338
# "100가구도 다 찾아라"…공급 대책으로 국유지 틈새 부지 발굴 https://n.news.naver.com/mnews/article/015/0005318946
#  https://n.news.naver.com/mnews/article/comment/015/0005318946
# 한전기술, 분기 실적 쇼크에 목표가 하향 "모멘텀 기다릴 때" https://n.news.naver.com/mnews/article/014/0005559132
#  https://n.news.naver.com/mnews/article/comment/014/0005559132
# 부모 사망 직전 형에게 이체된 돈, 돌려받을 수 있을까 [상속리포트] https://n.news.naver.com/mnews/article/020/0003739667
#  https://n.news.naver.com/mnews/article/comment/020/0003739667

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    'referer':''
}

img_urls = [
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_1.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_2.jpg',
    'https://image-comic.pstatic.net/webtoon/798173/5/20220804112251_d97bd1e1b38f0cd022e4e3639d2926b3_IMAG01_3.jpg'
]

for img_url in img_urls:
    pass
    # requests 의 get(url, headers) 함수 호출하기 
        
        # binary 응답 데이터 가져오기
        
        # url에서 파일명만 추출하기
        
        # binday data를 file에 write하기

# %% [markdown]
# * 현재 요청된 페이지의 image 모두 다운로드 해보기

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_files = {
    
}
#print(upload_files)

url = 'http://httpbin.org/post'
# file 업로드 하려면 requests의 post 함수에 files 속성을 사용합니다.
# Out:
# 200

# %% [markdown]
# ### .env 파일에서 환경변수 읽어오기
# * CLIENT_ID와 CLIENT_SECRET 환경변수 읽어오기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %% [markdown]
# ### 4. 캡챠(이미지) API 호출하기
# * urllib 사용
# * [네이버개발자가이드](https://developers.naver.com/docs/utils/captcha/examples/)
# * 1. 캡차 키 발급 요청
#   2. 캡차 이미지 요청
#   3. 사용자 입력값 검증 요청

# %%
# 캡차 키 발급 요청

# %%
# 캡차 이미지 요청

# %%
#  사용자 입력값 검증 요청

# %% [markdown]
# ### 5-1. 블로그 검색하기
# * 네이버 개발자센터에서 제공하는 검색 API 사용하기

# %%
import requests
from pprint import pprint

headers = {
    'X-Naver-Client-Id': CLIENT_ID,
    'X-Naver-Client-Secret': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)

# json() 함수로 응답 결과 가져오기 [{},{},{}]
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %% [markdown]
# ### 5-2. 블로그 검색하기
# * 네이버 API HUB (NAVER Cloud)에서 제공하는 검색 API 사용하기

# %%
from dotenv import load_dotenv
import os

load_dotenv()

CLIENT_ID = os.getenv("CLIENT_ID")
print(CLIENT_ID[:4])

CLIENT_SECRET = os.getenv("CLIENT_SECRET")
print(CLIENT_SECRET[:4])

# %%
import requests
from pprint import pprint

headers = {
    'X-NCP-APIGW-API-KEY-ID': CLIENT_ID,
    'X-NCP-APIGW-API-KEY': CLIENT_SECRET,
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}
domain_url = 'https://naverapihub.apigw.ntruss.com'
url = f'{domain_url}/search/v1/blog'

# requests get(url, params, headers) 요청 
res = requests.get(url, params=payload, headers=headers)
# json() 함수로 응답 결과 가져오기 [{},{},{}]
print(len(res.json()['items'])) 
pprint(res.json()['items'])

items_data = res.json()['items']
# 'title' , 'bloggername' , 'description' , 'bloggerlink' , 'link'

# %%
# data/blog.json 파일 생성하기
import json

with open('data/blog.json','w', encoding='utf-8') as file:
    json.dump(items_data, file)
