# %%
import requests
from bs4 import BeautifulSoup
import re

headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

member_list_300 = []
for index in range(1,31):
    url = f'https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex={index}'
    print(url)
    res = requests.get(url, headers=headers)
    #print(res.status_code)
    if res.ok:
        #print(res.json()['resultList'])
        member_list_10 = []
        for member in res.json()['resultList']:
            member_list_10.append(member) 
        
        #print(member_list_10)
        member_list_300.extend(member_list_10)
    else:
        print(res.status_code)
print(len(member_list_300))
print(member_list_300[:3])
# Out:
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=1
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=2
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=3
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=4
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=5
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=6
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=7
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=8
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=9
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=10
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=11
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=12
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=13
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=14
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=15
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=16
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=17
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=18
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=19
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=20
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=21
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=22
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=23
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=24
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=25
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=26
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=27
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=28
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=29
# https://www.assembly.go.kr/portal/cnts/cntsNaas/findNaasThx01.json?pageIndex=30
# 299
# [{'rnum': 1, 'monaCd': 'T2T8225E', 'hgNm': '강경숙', 'openNaId': 'KANGKYUNGSOOK', 'st': '22', 'unitNm': '제22대', 'polyNm': '조국혁신당', 'origNm': '비례대표', 'electGbnNm': '비례대표', 'cmitNm': '교육위원회, 예산결산특별위원회', 'reeleGbnNm': '초선', 'sexGbnNm': '여', 'mImgUrl': '/static/portal/img/openassm/new/68f83caf0c9e4546b1694ead863f45ce.jpg', 'mThumbImgUrl': '/static/portal/img/openassm/new/thumb/68f83caf0c9e4546b1694ead863f45ce.jpg', 'mLinkUrl': '/members/22nd/KANGKYUNGSOOK'}, {'rnum': 2, 'monaCd': 'L2I9861C', 'hgNm': '강대식', 'openNaId': 'KANGDAESIK', 'st': '22', 'unitNm': '제22대', 'polyNm': '국민의힘', 'origNm': '대구 동구군위군을', 'electGbnNm': '지역구', 'cmitNm': '국토교통위원회, 예산결산특별위원회', 'reeleGbnNm': '재선', 'sexGbnNm': '남', 'mImgUrl': '/static/portal/img/openassm/new/d1fe9f0902d84f0ba74f721d3298be7f.png', 'mThumbImgUrl': '/static/portal/img/openassm/new/thumb/d1fe9f0902d84f0ba74f721d3298be7f.png', 'mLinkUrl': '/members/22nd/KANGDAESIK'}, {'rnum': 3, 'monaCd': '8P37634C', 'hgNm': '강득구', 'openNaId': 'KANGDEUKGU', 'st': '22', 'unitNm': '제22대', 'polyNm': '더불어민주당', 'origNm': '경기 안양시만안구', 'electGbnNm': '지역구', 'cmitNm': '기후위기 특별위원회, 국토교통위원회', 'reeleGbnNm': '재선', 'sexGbnNm': '남', 'mImgUrl': '/static/portal/img/openassm/new/0410a0c8e24b474cac2fd79c7700ca2f.jpg', 'mThumbImgUrl': '/static/portal/img/openassm/new/thumb/0410a0c8e24b474cac2fd79c7700ca2f.jpg', 'mLinkUrl': '/members/22nd/KANGDEUKGU'}]

# %%
from pprint import pprint

pprint(member_list_300[:3])

# %% [markdown]
# #### Json 데이터와 상세페이지 스크래핑 데이터 를 혼합해서 상세정보 저장하기

# %%
import requests
from bs4 import BeautifulSoup
import re
from urllib.parse import urljoin

print('===> 스크래핑 시작')
#297명의 정보를 저장하는 List
member_detail_list = []

headers = {
    'user-agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/74.0.3729.169 Safari/537.36'
}

'''
    {'cmitNm': '교육위원회, 예산결산특별위원회',
    'electGbnNm': '비례대표',
    'hgNm': '강경숙',
    'mImgUrl': '/static/portal/img/openassm/new/68f83caf0c9e4546b1694ead863f45ce.jpg',
    'mLinkUrl': '/members/22nd/KANGKYUNGSOOK',
    'mThumbImgUrl': '/static/portal/img/openassm/new/thumb/68f83caf0c9e4546b1694ead863f45ce.jpg',
    'monaCd': 'T2T8225E',
    'openNaId': 'KANGKYUNGSOOK',
    'origNm': '비례대표',
    'polyNm': '조국혁신당',
    'reeleGbnNm': '초선',
    'rnum': 1,
    'sexGbnNm': '여',
    'st': '22',
    'unitNm': '제22대'}
'''
for idx,member in enumerate(member_list_300,1):
    # 타겟별 uniqe url 링크
    mem_sub_link = member['mLinkUrl']
    detail_url = f'https://www.assembly.go.kr{mem_sub_link}'
    res = requests.get(detail_url, headers=headers)
    print(res.ok, idx, detail_url)
    
    if res.ok:
        soup = BeautifulSoup(res.text, 'html.parser')
        
        #1명의 정보를 저장하는 dict 선언
        member_detail_dict = {}

        # 4번째 li부터
        li_tags = soup.select('ul.list li:nth-of-type(n+4)')
        #print(li_tags)
        # for li in li_tags:
        #     print(type(li.find('dt')))
        #     print(li.find('dt').text)

        # li_tags - ResultSet 객체, li_tag - Tag 객체
        
        dt_list = [li_tag.find('dt').text for li_tag in li_tags]
        # print(dt_list)

        dd_list = []        
        for li_tag in li_tags:
            dd_tag = li_tag.find('dd')
            pattern = re.compile(f'[\n\r\t]')
            dd_text = pattern.sub('',dd_tag.text.strip()).replace(" ","")
            dd_list.append(dd_text)
        # print(dd_list)
        
        member_detail_dict = dict(zip(dt_list, dd_list))

        member_detail_dict['이름'] = member['hgNm']        
        member_detail_dict['정당'] = member['polyNm']
        member_detail_dict['성별'] = member['sexGbnNm']
        member_detail_dict['선거구'] = member['origNm']
        member_detail_dict['지역비례'] = member['electGbnNm']

        sosok = member['cmitNm']
        if sosok is not None:
            idx = sosok.find(',')
            if idx > -1:            
                member_detail_dict['소속위원회'] = sosok[:idx]
            else:
                member_detail_dict['소속위원회'] = sosok
        else:        
            member_detail_dict['소속위원회'] = ''    

        # print(member_detail_dict['소속위원회'])                        
        
        member_detail_dict['당선횟수'] = member['reeleGbnNm']
        
        img_sub_url = member['mThumbImgUrl']
        img_url = urljoin(detail_url,img_sub_url)
        #print(img_url)
        member_detail_dict['이미지'] = img_url
        
        # pprint(member_detail_dict)        
                        
        #1명의 정보가 저장된 dict를 list에 추가하기
        member_detail_list.append(member_detail_dict)
    else:
        print(res.status_code)
        
print(len(member_detail_list))
print(member_detail_list[:2])
print('===> 스크래핑 끝')
# Out:
# ===> 스크래핑 시작
# True 1 https://www.assembly.go.kr/members/22nd/KANGKYUNGSOOK
# True 2 https://www.assembly.go.kr/members/22nd/KANGDAESIK
# True 3 https://www.assembly.go.kr/members/22nd/KANGDEUKGU
# True 4 https://www.assembly.go.kr/members/22nd/KANGMYOUNGGU
# True 5 https://www.assembly.go.kr/members/22nd/KANGMINKUK
# True 6 https://www.assembly.go.kr/members/22nd/KANGSUNYOUNG
# True 7 https://www.assembly.go.kr/members/22nd/KANGSUNWOO
# True 8 https://www.assembly.go.kr/members/22nd/KangSeungKyoo
# True 9 https://www.assembly.go.kr/members/22nd/KANGJUNHYEON
# True 10 https://www.assembly.go.kr/members/22nd/KOHDONGJIN
# True 11 https://www.assembly.go.kr/members/22nd/KOMINJUNG
# True 12 https://www.assembly.go.kr/members/22nd/KWAKKYUTAEK
# True 13 https://www.assembly.go.kr/members/22nd/KWAKSANGEON
# True 14 https://www.assembly.go.kr/members/22nd/KUJAKEUN
# True 15 https://www.assembly.go.kr/members/22nd/KWONYOUNGSE
# True 16 https://www.assembly.go.kr/members/22nd/KwonYoungJin
# True 17 https://www.assembly.go.kr/members/22nd/KWONCHILSEUNG
# True 18 https://www.assembly.go.kr/members/22nd/KWONHYANGYUP
# True 19 https://www.assembly.go.kr/members/22nd/KIMGUNN
# True 20 https://www.assembly.go.kr/members/22nd/KIMKYOHEUNG
# True 21 https://www.assembly.go.kr/members/22nd/KIMKIWOONG
# True 22 https://www.assembly.go.kr/members/22nd/KIMGIPYO
# True 23 https://www.assembly.go.kr/members/22nd/KIMGIHYEON
# True 24 https://www.assembly.go.kr/members/22nd/KIMNAMKUK
# True 25 https://www.assembly.go.kr/members/22nd/KIMNAMGEUN
# True 26 https://www.assembly.go.kr/members/22nd/KIMNAMJOON
# True 27 https://www.assembly.go.kr/members/22nd/KIMNAMHEE
# True 28 https://www.assembly.go.kr/members/22nd/KIMDAISIK
# True 29 https://www.assembly.go.kr/members/22nd/KIMDOEUP
# True 30 https://www.assembly.go.kr/members/22nd/KIMDONGAH
# True 31 https://www.assembly.go.kr/members/22nd/KIMMOONSOO
# True 32 https://www.assembly.go.kr/members/22nd/KIMMIAE
# True 33 https://www.assembly.go.kr/members/22nd/KIMMINSEOK
# True 34 https://www.assembly.go.kr/members/22nd/KIMMEENGEON
# True 35 https://www.assembly.go.kr/members/22nd/KIMBYUNGKEE
# True 36 https://www.assembly.go.kr/members/22nd/KIMBYUNGJOO
# True 37 https://www.assembly.go.kr/members/22nd/KIMSANGHOON
# True 38 https://www.assembly.go.kr/members/22nd/KIMSEOKKI
# True 39 https://www.assembly.go.kr/members/22nd/KIMSUNGYO
# True 40 https://www.assembly.go.kr/members/22nd/KIMSUNMIN
# True 41 https://www.assembly.go.kr/members/22nd/KIMSUNGBUM
# True 42 https://www.assembly.go.kr/members/22nd/KIMSUNGWON
# True 43 https://www.assembly.go.kr/members/22nd/KIMSUNGWHAN
# True 44 https://www.assembly.go.kr/members/22nd/KIMSUNGHOI
# True 45 https://www.assembly.go.kr/members/22nd/KIMSOHEE
# True 46 https://www.assembly.go.kr/members/22nd/KIMSEUNGSU
# True 47 https://www.assembly.go.kr/members/22nd/KIMSEUNGWON
# True 48 https://www.assembly.go.kr/members/22nd/KIMYOUNGBAE
# True 49 https://www.assembly.go.kr/members/22nd/KIMYOUNGJIN
# True 50 https://www.assembly.go.kr/members/22nd/KIMYOUNGHO
# True 51 https://www.assembly.go.kr/members/22nd/KIMYOUNGWHAN
# True 52 https://www.assembly.go.kr/members/22nd/KIMYEAJI
# True 53 https://www.assembly.go.kr/members/22nd/KIMYONGMAN
# True 54 https://www.assembly.go.kr/members/22nd/KIMYONGMIN
# True 55 https://www.assembly.go.kr/members/22nd/YONGTAEKIM
# True 56 https://www.assembly.go.kr/members/22nd/KIMWOOYOUNG
# True 57 https://www.assembly.go.kr/members/22nd/KIMWONI
# True 58 https://www.assembly.go.kr/members/22nd/KIMWISANG
# True 59 https://www.assembly.go.kr/members/22nd/KIMYOON
# True 60 https://www.assembly.go.kr/members/22nd/KIMYUNDUK
# True 61 https://www.assembly.go.kr/members/22nd/KIMEUNHYE
# True 62 https://www.assembly.go.kr/members/22nd/KIMEUIKYEOM
# True 63 https://www.assembly.go.kr/members/22nd/KIMJANGKYOM
# True 64 https://www.assembly.go.kr/members/22nd/KIMJAESUB
# True 65 https://www.assembly.go.kr/members/22nd/JAEWONK
# True 66 https://www.assembly.go.kr/members/22nd/KIMJUNGJAE
# True 67 https://www.assembly.go.kr/members/22nd/KIMJUNGHO
# True 68 https://www.assembly.go.kr/members/22nd/KIMJONGMIN
# True 69 https://www.assembly.go.kr/members/22nd/KIMJONGYANG
# True 70 https://www.assembly.go.kr/members/22nd/KIMJUYOUNG
# True 71 https://www.assembly.go.kr/members/22nd/KIMJUNHYUK
# True 72 https://www.assembly.go.kr/members/22nd/KIMJOONHYUNG
# True 73 https://www.assembly.go.kr/members/22nd/KimJoonHwan
# True 74 https://www.assembly.go.kr/members/22nd/KIMTAEKYU
# True 75 https://www.assembly.go.kr/members/22nd/KIMTAENYEON
# True 76 https://www.assembly.go.kr/members/22nd/KIMTAESEON
# True 77 https://www.assembly.go.kr/members/22nd/KIMTAEHO
# True 78 https://www.assembly.go.kr/members/22nd/KIMHANKYU
# True 79 https://www.assembly.go.kr/members/22nd/KIMHyun
# True 80 https://www.assembly.go.kr/members/22nd/KIMHYUNJUNG
# True 81 https://www.assembly.go.kr/members/22nd/KIMHYUNGDONG
# True 82 https://www.assembly.go.kr/members/22nd/KIMHeeJung
# True 83 https://www.assembly.go.kr/members/22nd/NAKYUNGWON
# True 84 https://www.assembly.go.kr/members/22nd/NAMINSOON
# True 85 https://www.assembly.go.kr/members/22nd/NOHJONGMYUN
# True 86 https://www.assembly.go.kr/members/22nd/MAENGSUNGKYU
# True 87 https://www.assembly.go.kr/members/22nd/MOGYEONGJONG
# True 88 https://www.assembly.go.kr/members/22nd/MUNGEUMJU
# True 89 https://www.assembly.go.kr/members/22nd/MOONDAELIM
# True 90 https://www.assembly.go.kr/members/22nd/MOONJEONGBOG
# True 91 https://www.assembly.go.kr/members/22nd/MOONJINSEOG
# True 92 https://www.assembly.go.kr/members/22nd/MINBYOUNGDUG
# True 93 https://www.assembly.go.kr/members/22nd/MINHONGCHUL
# True 94 https://www.assembly.go.kr/members/22nd/PARKKYOONTAEK
# True 95 https://www.assembly.go.kr/members/22nd/PARKDAECHUL
# True 96 https://www.assembly.go.kr/members/22nd/PARKDUKHYUM
# True 97 https://www.assembly.go.kr/members/22nd/PARKMINKYU
# True 98 https://www.assembly.go.kr/members/22nd/PARKBEOMKYE
# True 99 https://www.assembly.go.kr/members/22nd/PARKSANGWOONG
# True 100 https://www.assembly.go.kr/members/22nd/PARKSANGHYUK
# True 101 https://www.assembly.go.kr/members/22nd/PARKSUNWON
# True 102 https://www.assembly.go.kr/members/22nd/PARKSEONGMIN
# True 103 https://www.assembly.go.kr/members/22nd/PARKSUNGJOON
# True 104 https://www.assembly.go.kr/members/22nd/PARKSUNGHOON
# True 105 https://www.assembly.go.kr/members/22nd/PARKSOOMIN
# True 106 https://www.assembly.go.kr/members/22nd/PARKSOOYOUNG
# True 107 https://www.assembly.go.kr/members/22nd/PARKYONGKAB
# True 108 https://www.assembly.go.kr/members/22nd/PARKEUNJUNG
# True 109 https://www.assembly.go.kr/members/22nd/PARKJEUNG
# True 110 https://www.assembly.go.kr/members/22nd/PARKJEONGHA
# True 111 https://www.assembly.go.kr/members/22nd/PARKJEONGHYEON
# True 112 https://www.assembly.go.kr/members/22nd/PARKJEONGHUN
# True 113 https://www.assembly.go.kr/members/22nd/PARKJUMIN
# True 114 https://www.assembly.go.kr/members/22nd/PARKJUNTAE
# True 115 https://www.assembly.go.kr/members/22nd/PARKJIEWON
# True 116 https://www.assembly.go.kr/members/22nd/PARKJIWON
# True 117 https://www.assembly.go.kr/members/22nd/PARKJEEHYE
# True 118 https://www.assembly.go.kr/members/22nd/PARKCHOONGKWON
# True 119 https://www.assembly.go.kr/members/22nd/PARKHAECHEOL
# True 120 https://www.assembly.go.kr/members/22nd/PARKHYEUNGSOO
# True 121 https://www.assembly.go.kr/members/22nd/PARKHONGKEUN
# True 122 https://www.assembly.go.kr/members/22nd/PARKHONGBAE
# True 123 https://www.assembly.go.kr/members/22nd/PARKHEESEONG
# True 124 https://www.assembly.go.kr/members/22nd/BAEJUNEYOUNG
# True 125 https://www.assembly.go.kr/members/22nd/BAEHYUNJIN
# True 126 https://www.assembly.go.kr/members/22nd/BAEKSUNHEE
# True 127 https://www.assembly.go.kr/members/22nd/BAKSEUNGA
# True 128 https://www.assembly.go.kr/members/22nd/BAEKJONGHEAN
# True 129 https://www.assembly.go.kr/members/22nd/BACKHYERYUN
# True 130 https://www.assembly.go.kr/members/22nd/BOKKIWANG
# True 131 https://www.assembly.go.kr/members/22nd/BOOSEUNGCHAN
# True 132 https://www.assembly.go.kr/members/22nd/SUHMYUNGOK
# True 133 https://www.assembly.go.kr/members/22nd/SEOMIHWA
# True 134 https://www.assembly.go.kr/members/22nd/SUHBUMSOO
# True 135 https://www.assembly.go.kr/members/22nd/SEOSAMSEOK
# True 136 https://www.assembly.go.kr/members/22nd/SEOYOUNGKYO
# True 137 https://www.assembly.go.kr/members/22nd/SEOYOUNGSEOK
# True 138 https://www.assembly.go.kr/members/22nd/SEOWANGJIN
# True 139 https://www.assembly.go.kr/members/22nd/SEOILJUN
# True 140 https://www.assembly.go.kr/members/22nd/SEOJIYOUNG
# True 141 https://www.assembly.go.kr/members/22nd/SUHCHEONHO
# True 142 https://www.assembly.go.kr/members/22nd/SUNGILJONG
# True 143 https://www.assembly.go.kr/members/22nd/SOBYUNGHOON
# True 144 https://www.assembly.go.kr/members/22nd/SONMYOUNGSOO
# True 145 https://www.assembly.go.kr/members/22nd/SONSOL
# True 146 https://www.assembly.go.kr/members/22nd/SONGKIHUN
# True 147 https://www.assembly.go.kr/members/22nd/SONGSEOGJUN
# True 148 https://www.assembly.go.kr/members/22nd/SONGEONSEOG
# True 149 https://www.assembly.go.kr/members/22nd/SONGYOUNGGIL
# True 150 https://www.assembly.go.kr/members/22nd/SONGOKJOO
# True 151 https://www.assembly.go.kr/members/22nd/SONGJAEBONG
# True 152 https://www.assembly.go.kr/members/22nd/SHINDONGUK
# True 153 https://www.assembly.go.kr/members/22nd/SHINSungBum
# True 154 https://www.assembly.go.kr/members/22nd/SHINCHANGSIK
# True 155 https://www.assembly.go.kr/members/22nd/SHINJEONGHOON
# True 156 https://www.assembly.go.kr/members/22nd/AHNGYUBACK
# True 157 https://www.assembly.go.kr/members/22nd/AHNDOGEOL
# True 158 https://www.assembly.go.kr/members/22nd/AHNSANGHOON
# True 159 https://www.assembly.go.kr/members/22nd/AHNCHEOLSOO
# True 160 https://www.assembly.go.kr/members/22nd/ANTAEJUN
# True 161 https://www.assembly.go.kr/members/22nd/ANHOYOUNG
# True 162 https://www.assembly.go.kr/members/22nd/YANGBUNAM
# True 163 https://www.assembly.go.kr/members/22nd/EOHKIYKU
# True 164 https://www.assembly.go.kr/members/22nd/EOMTAEYOUNG
# True 165 https://www.assembly.go.kr/members/22nd/YEOMTAEYOUNG
# True 166 https://www.assembly.go.kr/members/22nd/OHGIHYOUNG
# True 167 https://www.assembly.go.kr/members/22nd/OHSAEHEE
# True 168 https://www.assembly.go.kr/members/22nd/YONGHYEIN
# True 169 https://www.assembly.go.kr/members/22nd/WOOWONSHIK
# True 170 https://www.assembly.go.kr/members/22nd/WOOJAEJUN
# True 171 https://www.assembly.go.kr/members/22nd/YOODONGSOO
# True 172 https://www.assembly.go.kr/members/22nd/YOOSANGBUM
# True 173 https://www.assembly.go.kr/members/22nd/YOOYEONGHA
# True 174 https://www.assembly.go.kr/members/22nd/YUYONGWEON
# True 175 https://www.assembly.go.kr/members/22nd/YUEUIDONG
# True 176 https://www.assembly.go.kr/members/22nd/YOUNKUNYOUNG
# True 177 https://www.assembly.go.kr/members/22nd/YOONSANGHYUN
# True 178 https://www.assembly.go.kr/members/22nd/YOONYOUNGSEOK
# True 179 https://www.assembly.go.kr/members/22nd/YUNYONGKEUN
# True 180 https://www.assembly.go.kr/members/22nd/YUNJAEOK
# True 181 https://www.assembly.go.kr/members/22nd/YOONJONGKUN
# True 182 https://www.assembly.go.kr/members/22nd/YOONJONGO
# True 183 https://www.assembly.go.kr/members/22nd/YOONJOONBYEONG
# True 184 https://www.assembly.go.kr/members/22nd/YOONHANHONG
# True 185 https://www.assembly.go.kr/members/22nd/YUNHOJUNG
# True 186 https://www.assembly.go.kr/members/22nd/YOONHUDUK
# True 187 https://www.assembly.go.kr/members/22nd/LEEKANGILL
# True 188 https://www.assembly.go.kr/members/22nd/LEEKAIHO
# True 189 https://www.assembly.go.kr/members/22nd/LEEGEONTAE
# True 190 https://www.assembly.go.kr/members/22nd/LEEKWANGJAE
# True 191 https://www.assembly.go.kr/members/22nd/LEEGOANGHEE
# True 192 https://www.assembly.go.kr/members/22nd/LEEKIHEON
# True 193 https://www.assembly.go.kr/members/22nd/LEEDALHEE
# True 194 https://www.assembly.go.kr/members/22nd/LEEMANHEE
# True 195 https://www.assembly.go.kr/members/22nd/LEESANGSIK
# True 196 https://www.assembly.go.kr/members/22nd/LEESANGHWI
# True 197 https://www.assembly.go.kr/members/22nd/LEESEONGKWEUN
# True 198 https://www.assembly.go.kr/members/22nd/LEESUNGYOON
# True 199 https://www.assembly.go.kr/members/22nd/LEESOYOUNG
# True 200 https://www.assembly.go.kr/members/22nd/LEESOHEE
# True 201 https://www.assembly.go.kr/members/22nd/LEESOOJIN
# True 202 https://www.assembly.go.kr/members/22nd/LEEYANGSOO
# True 203 https://www.assembly.go.kr/members/22nd/LEEUNJU
# True 204 https://www.assembly.go.kr/members/22nd/LEEYEONHEE
# True 205 https://www.assembly.go.kr/members/22nd/LEEYONGSUN
# True 206 https://www.assembly.go.kr/members/22nd/YONGWOOLEE
# True 207 https://www.assembly.go.kr/members/22nd/LEEINSEON
# True 208 https://www.assembly.go.kr/members/22nd/LEEINYOUNG
# True 209 https://www.assembly.go.kr/members/22nd/LEEJAEGANG
# True 210 https://www.assembly.go.kr/members/22nd/LEEJAEKWAN
# True 211 https://www.assembly.go.kr/members/22nd/LEEJAEJUNG
# True 212 https://www.assembly.go.kr/members/22nd/LEEJUNGMUN
# True 213 https://www.assembly.go.kr/members/22nd/LEEJEONGHEON
# True 214 https://www.assembly.go.kr/members/22nd/LEEJONGBAE
# True 215 https://www.assembly.go.kr/members/22nd/LEEJONHWOOK
# True 216 https://www.assembly.go.kr/members/22nd/JUYOUNGLEE
# True 217 https://www.assembly.go.kr/members/22nd/LeeJuhee
# True 218 https://www.assembly.go.kr/members/22nd/LEEJUNSEOK
# True 219 https://www.assembly.go.kr/members/22nd/LEEJINSOOK
# True 220 https://www.assembly.go.kr/members/22nd/LEECHULGYU
# True 221 https://www.assembly.go.kr/members/22nd/LEECHOONSUAK
# True 222 https://www.assembly.go.kr/members/22nd/LEEHACKYOUNG
# True 223 https://www.assembly.go.kr/members/22nd/LEEHAIMIN
# True 224 https://www.assembly.go.kr/members/22nd/LEEHAESIK
# True 225 https://www.assembly.go.kr/members/22nd/LEEHUNSEUNG
# True 226 https://www.assembly.go.kr/members/22nd/LEEHOONKI
# True 227 https://www.assembly.go.kr/members/22nd/LIMMUNYEONG
# True 228 https://www.assembly.go.kr/members/22nd/LIMMIAE
# True 229 https://www.assembly.go.kr/members/22nd/LIMOKYEONG
# True 230 https://www.assembly.go.kr/members/22nd/LIMLEEJA
# True 231 https://www.assembly.go.kr/members/22nd/LIMJONGDEUK
# True 232 https://www.assembly.go.kr/members/22nd/LIMHOSEON
# True 233 https://www.assembly.go.kr/members/22nd/JANGKYUNGTAE
# True 234 https://www.assembly.go.kr/members/22nd/JANGDONGHYEOK
# True 235 https://www.assembly.go.kr/members/22nd/CHANGJONGTAE
# True 236 https://www.assembly.go.kr/members/22nd/CHULMINJANG
# True 237 https://www.assembly.go.kr/members/22nd/JEONYONGGI
# True 238 https://www.assembly.go.kr/members/22nd/JEONEUNSU
# True 239 https://www.assembly.go.kr/members/22nd/CHUNJONGDUK
# True 240 https://www.assembly.go.kr/members/22nd/JEONJINSOOK
# True 241 https://www.assembly.go.kr/members/22nd/JEONHYUNHEUI
# True 242 https://www.assembly.go.kr/members/22nd/JEONGDONGMAN
# True 243 https://www.assembly.go.kr/members/22nd/CHUNGDONGYOUNG
# True 244 https://www.assembly.go.kr/members/22nd/JUNGSUNGKOOK
# True 245 https://www.assembly.go.kr/members/22nd/JUNGSUNGHO
# True 246 https://www.assembly.go.kr/members/22nd/JUNGYEONWOOK
# True 247 https://www.assembly.go.kr/members/22nd/CHUNGILYOUNG
# True 248 https://www.assembly.go.kr/members/22nd/JEONGJEOMSIG
# True 249 https://www.assembly.go.kr/members/22nd/JEONGJUNHO
# True 250 https://www.assembly.go.kr/members/22nd/CHUNGCHINOOK
# True 251 https://www.assembly.go.kr/members/22nd/JUNGCHUNGRAE
# True 252 https://www.assembly.go.kr/members/22nd/CHUNGCHOONSAENG
# True 253 https://www.assembly.go.kr/members/22nd/JUNGTAEHO
# True 254 https://www.assembly.go.kr/members/22nd/JEONGHYEKYEONG
# True 255 https://www.assembly.go.kr/members/22nd/JUNGHEEYONG
# True 256 https://www.assembly.go.kr/members/22nd/CHOKYOUNGTAE
# True 257 https://www.assembly.go.kr/members/22nd/CHOGYEWON
# True 258 https://www.assembly.go.kr/members/22nd/CHOBAESOOK
# True 259 https://www.assembly.go.kr/members/22nd/JOSEOUNGLAE
# True 260 https://www.assembly.go.kr/members/22nd/CHOSEUNGHWAN
# True 261 https://www.assembly.go.kr/members/22nd/CHOEUNHEE
# True 262 https://www.assembly.go.kr/members/22nd/CHOINCHEUL
# True 263 https://www.assembly.go.kr/members/22nd/CHOJEONGSIK
# True 264 https://www.assembly.go.kr/members/22nd/CHOJUNGHUN
# True 265 https://www.assembly.go.kr/members/22nd/CHOJIYEON
# True 266 https://www.assembly.go.kr/members/22nd/JOOJINWOO
# True 267 https://www.assembly.go.kr/members/22nd/JUCHEOLHYEON
# True 268 https://www.assembly.go.kr/members/22nd/JOOHOYOUNG
# True 269 https://www.assembly.go.kr/members/22nd/JINSUNMEE
# True 270 https://www.assembly.go.kr/members/22nd/JINSUNGJOON
# True 271 https://www.assembly.go.kr/members/22nd/JINJONGOH
# True 272 https://www.assembly.go.kr/members/22nd/CHAGYUGEUN
# True 273 https://www.assembly.go.kr/members/22nd/CHAJIHO
# True 274 https://www.assembly.go.kr/members/22nd/CHAIHYUNIL
# True 275 https://www.assembly.go.kr/members/22nd/CHEONJUNHO
# True 276 https://www.assembly.go.kr/members/22nd/CHUNHARAM
# True 277 https://www.assembly.go.kr/members/22nd/CHOIKISANG
# True 278 https://www.assembly.go.kr/members/22nd/CHOIMinhee
# True 279 https://www.assembly.go.kr/members/22nd/CHOIBOYUN
# True 280 https://www.assembly.go.kr/members/22nd/CHOISOOJIN
# True 281 https://www.assembly.go.kr/members/22nd/CHOIEUNSEOK
# True 282 https://www.assembly.go.kr/members/22nd/ChoiHyuckJin
# True 283 https://www.assembly.go.kr/members/22nd/CHOIHYUNGDU
# True 284 https://www.assembly.go.kr/members/22nd/HANKIHO
# True 285 https://www.assembly.go.kr/members/22nd/HANDONGHOON
# True 286 https://www.assembly.go.kr/members/22nd/HANMINSOO
# True 287 https://www.assembly.go.kr/members/22nd/HANBYUNGDO
# True 288 https://www.assembly.go.kr/members/22nd/HANJEOUNGAE
# True 289 https://www.assembly.go.kr/members/22nd/HANJUNHO
# True 290 https://www.assembly.go.kr/members/22nd/HANZEEA
# True 291 https://www.assembly.go.kr/members/22nd/HANCHANGMIN
# True 292 https://www.assembly.go.kr/members/22nd/HUHSUNGMOO
# True 293 https://www.assembly.go.kr/members/22nd/HUHYOUNG
# True 294 https://www.assembly.go.kr/members/22nd/HEOJONGSIK
# True 295 https://www.assembly.go.kr/members/22nd/HONGKEEWON
# True 296 https://www.assembly.go.kr/members/22nd/HWANGMYEONGSEON
# True 297 https://www.assembly.go.kr/members/22nd/HWANGUNHA
# True 298 https://www.assembly.go.kr/members/22nd/HWANGJUNGA
# True 299 https://www.assembly.go.kr/members/22nd/HWANGHEE
# 299
# [{'사무실 전화': '02-784-5601', '사무실 호실': '의원회관515호', '개별 홈페이지': 'https://blog.naver.com/grace6752', '이메일': 'gracesook52@rebuildingk.kr', '보좌관': '서용선,이화정', '선임비서관': '김홍,오세령', '비서관': '유은영,김은민,이경열,김한올,김희경,채윤아', '의원실 안내': '', '이름': '강경숙', '정당': '조국혁신당', '성별': '여', '선거구': '비례대표', '지역비례': '비례대표', '소속위원회': '교육위원회', '당선횟수': '초선', '이미지': 'https://www.assembly.go.kr/static/portal/img/openassm/new/thumb/68f83caf0c9e4546b1694ead863f45ce.jpg'}, {'사무실 전화': '02-784-5275', '사무실 호실': '의원회관341호', '개별 홈페이지': '', '이메일': 'kds21341@naver.com', '보좌관': '박홍규,유진영', '선임비서관': '이기백,장충석', '비서관': '박순권,김현정,박동혁,류고운,도다예', '의원실 안내': '', '이름': '강대식', '정당': '국민의힘', '성별': '남', '선거구': '대구 동구군위군을', '지역비례': '지역구', '소속위원회': '국토교통위원회', '당선횟수': '재선', '이미지': 'https://www.assembly.go.kr/static/portal/img/openassm/new/thumb/d1fe9f0902d84f0ba74f721d3298be7f.png'}]
# ===> 스크래핑 끝

# %% [markdown]
# #### 웹스크래핑한 데이터를 Pandas DataFrame객체로 저장하여 분석 및 시각화

# %%
import pandas as pd

member_df = pd.DataFrame(columns=['이름','정당','선거구','당선횟수','지역비례','성별','소속위원회','이미지','사무실 전화','사무실 호실',\
                                  '개별 홈페이지','이메일','보좌관','선임비서관','비서관','의원실 안내'])

for member_detail in member_detail_list:
    # Row 하나 생성
    df_new_row = pd.DataFrame.from_records([member_detail])
    member_df = pd.concat([member_df, df_new_row])
    # dict <=> Series
    #series_obj = pd.Series(member_detail)
    # Series 객체를 append 
    #member_df = member_df.append(series_obj, ignore_index=True)

print(member_df.columns)
print(member_df.shape)    
member_df.head(2)

# %%
# index가 1부터 시작하도록 재설정
member_df.reset_index(drop=True, inplace=True)
member_df.index = member_df.index + 1
print(member_df.index)
# Out:
# RangeIndex(start=1, stop=300, step=1)

# %%
import json

with open('data/members.json','w',encoding='utf-8') as file:
    json.dump(member_detail_list, file)

# %%
import pandas as pd

member_df = pd.read_json('data/members.json')
print(member_df.shape)
# Out:
# (299, 16)

# %%
member_df['정당'].unique()

# %%
member_df['정당'].value_counts()

# %%
member_df['당선횟수'].value_counts()

# %%
member_df.loc[member_df['당선횟수'] == '6선',['이름','정당']]

# %%
member_df.loc[member_df['당선횟수'].isin(['5선', '6선']), ['이름', '정당']].sort_values(by='정당').reset_index(drop=True)

# %%
member_df['성별'].value_counts(normalize=True)
# Out:
# 성별
# 남    0.785953
# 여    0.214047
# Name: proportion, dtype: float64

# %%
member_df['선거구'].value_counts()

# %%
#선거구2 컬럼을 새로 추가
#경남 창원시성산구 -> 경남
print(type(member_df['선거구']))
print(type(member_df['선거구'].str))
#Series객체를 StringMethods 객체로 변환(문자열 슬라이싱을 하기 위해서)
temp_str = member_df['선거구'].str
#2글자 슬라이싱 값을 선거구2 라는 컬럼으로 저장
member_df['선거구2'] = temp_str[:2]

member_df.loc[0:3,['선거구','선거구2']]

# %%
member_df['선거구2'].value_counts()

# %%
# Row Counting - normalize=True 속성은 % (퍼센티지) 비율로 나타냄
member_df['선거구2'].value_counts(normalize=True)

# %%
member_df['지역비례'].value_counts()

# %%
member_df['지역비례'].value_counts(normalize=True)

# %%
member_df['이미지'].tail()

# %%
from IPython.display import Image, display

for img_url in member_df['이미지'].sample(3):
    print(img_url)
    display(Image(url=img_url))

# %% [markdown]
# ### 시각화
# * Image 출력 - Image 객체, diplay() 함수 사용
# * seaborn - countplot, distplot, heatmap Plot 그려보기
# * maplotlib - histogram, pie  Plot 그려보기
# * 한글폰트 설정

# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm

import seaborn as sns

# %%
[ (font.name, font.fname) for font in fm.fontManager.ttflist if 'Mal' in font.name ] # if 'Mal' in font.name
# Out:
# [('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunbd.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgun.ttf'),
#  ('Malgun Gothic', 'C:\\Windows\\Fonts\\malgunsl.ttf')]

# %%
#한글폰트 설정
font_path = 'C:\\Windows\\Fonts\\malgun.ttf'
# font의 파일정보로 font name을 알아내기
font_prop = fm.FontProperties(fname=font_path).get_name()
print(font_prop)
# matplotlib의 rc(run command) 함수를 사용해서 폰트이름 설정
matplotlib.rc('font', family=font_prop)
# Out:
# Malgun Gothic

# %% [markdown]
# ### Seaborn 의 막대 그래프
# * barplot - x축과 y축을 둘 다 설정할 수 있음
# * countplot - x축 이나 y축 중에서 하나만 설정할 수 있음
#     * 범주형 속성을 가지는 데이터들의 히스토그램을 보여준다.
#     * 종류별로 count를 보여주는 Plot이다.

# %%
member_df['정당'].value_counts().index
# Out:
# Index(['더불어민주당', '국민의힘', '조국혁신당', '무소속', '진보당', '개혁신당', '기본소득당', '사회민주당'], dtype='object', name='정당')

# %%
figure, (axes1,axes2,axes3) = plt.subplots(nrows=3, ncols=1)
figure.set_size_inches(18,12)

sns.countplot(data=member_df, x='정당', ax=axes1, order=member_df['정당'].value_counts().index, hue='정당')
sns.countplot(data=member_df, x='당선횟수', ax=axes2, order=member_df['당선횟수'].value_counts().index, hue='당선횟수')
sns.countplot(data=member_df, y='성별', ax=axes3, order=member_df['성별'].value_counts().index, hue='성별')

plt.show()

# %% [markdown]
# #### Matplotlib 의 Pie Plot 그려보기

# %%
cdf = member_df['선거구2'].value_counts(normalize=True)
cdf

# %%
print(cdf.index)

# %%
# figure size 설정
figure = plt.figure(figsize=(20,12))
print(type(figure))
# pie() 함수 - pie plot을 그려주는 함수
plt.pie(cdf, labels=cdf.index, autopct='%1.1f%%', startangle=140, shadow=True)
# pie plot을 그릴때 원의 형태를 유지하도록 하는 설정
plt.axis('equal')
plt.title('선거구 분포값')
plt.show()

# %% [markdown]
# #### Seaborn의 HistPlot (분포도)
# * 히스토그램은 구간에 따른 Count를 표현하기 때문에, y는 count로 고정되어 있어 x값만 설정하면 됩니다. ( x 와 y 중에서 하나만 설정하면 됩니다.)
# * hue 옵션은 값에 따라 Plot의 색을 다르게 표현할 수 있다.
# * multiple = 'dodge'|'stack'

# %%
figure, axes1 = plt.subplots(nrows=1, ncols=1)
figure.set_size_inches(18,12)

sns.histplot(data=member_df, x='정당', ax=axes1, hue='성별', multiple='dodge',
             palette={'남': 'blue', '여': 'red'}, shrink=0.8)
plt.show()

# %%
member_df.loc[member_df['정당'] == '조국혁신당',['이름','성별']]

# %%
member_df.loc[member_df['정당'] == '조국혁신당',['이름','성별']].groupby('성별').count()

# %% [markdown]
# #### 다중 빈도 막대 그래프 catplot
# * 다중 빈도 막대그래프는 countplot() 또는 catplot() 이 있습니다.
# * hue 옵션은 변량을 색상으로 구분하는 파라미터입니다.

# %%
# 선거구 이름들이 빈도순으로 정렬된 리스트입니다.
s_index = member_df['선거구2'].value_counts().index
s_index
# Out:
# Index(['경기', '서울', '비례', '전남', '부산', '경남', '인천', '경북', '대구', '충남', '전북', '충북',
#        '대전', '강원', '울산', '제주', '세종'],
#       dtype='object', name='선거구2')

# %%
# catplot은 ax 속성이 없어 아래 코드는 사용 불가
# 사이즈 조정 시 height, aspect 사용

_ = sns.catplot(data=member_df, y='선거구2', hue='성별', kind='count',
             palette={'남': 'navy', '여': 'orange'},
             order=s_index, height=8, aspect=2)
plt.show()

# %% [markdown]
# #### 히스토그램을 만드는 displot
# * hue와 palette를 사용하여 색상을 지정할 수 있습니다.
# * col 옵션은 성별에 따라 서브플롯을 나누어서 그려줍니다.

# %%
_ = sns.displot(
    data=member_df,
    x='당선횟수',
    hue='성별',  # 성별에 따라 색상 구분
    col='성별',  # 성별에 따라 캔버스 구분
    palette={'남': 'blue', '여': 'orange'},  # 색상 지정
    kde=True,  # 커널 밀도 추정 곡선 추가 (선택 사항)
    height=5,  # 각 플롯의 높이
    aspect=1.5  # 각 플롯의 가로 세로 비율
)
plt.show()
